# %%
import cv2
pic = '/Users/nanzou/Documents/GitHub/walkr/mission/IMG_7840.PNG'

# %%
img = cv2.imread(pic)
#gaussed = cv2.GaussianBlur(pic, (3,3), 0)
cannyed = cv2.Canny(img, 10, 70)
cannyed2 = cv2.cvtColor(cannyed, cv2.COLOR_GRAY2BGR)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(contours)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d3c3a8ba8c81> in <module>
# ----> 1 plt.imshow(contours)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, binary = cv2.threshold(gray,1,255,cv2.THRESH_BINARY)

# %%
contours, hierarchy = cv2.findContours(binary,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)

# %%
hierarchy
# Out:
# array([[[-1, -1, -1, -1]]], dtype=int32)

# %%
img = cv2.pyrDown(cv2.imread(gray, cv2.IMREAD_UNCHANGED))
# threshold 函数对图像进行二化值处理，由于处理后图像对原图像有所变化，因此img.copy()生成新的图像，cv2.THRESH_BINARY是二化值
ret, thresh = cv2.threshold(cv2.cvtColor(img.copy(), cv2.COLOR_BGR2GRAY), 127, 255, cv2.THRESH_BINARY)
# findContours函数查找图像里的图形轮廓

image, contours, hier = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

for c in contours:
    # 轮廓绘制方法一
    # boundingRect函数计算边框值，x，y是坐标值，w，h是矩形的宽和高
    x, y, w, h = cv2.boundingRect(c)
    # 在img图像画出矩形，(x, y), (x + w, y + h)是矩形坐标，(0, 255, 0)设置通道颜色，2是设置线条粗度
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # 轮廓绘制方法二
    # 查找最小区域
    rect = cv2.minAreaRect(c)
    # 计算最小面积矩形的坐标
    box = cv2.boxPoints(rect)
    # 将坐标规范化为整数
    box = np.int0(box)
    # 绘制矩形
    cv2.drawContours(img, [box], 0, (0, 0, 255), 3)

    # 轮廓绘制方法三
    # 圆心坐标和半径的计算
    (x, y), radius = cv2.minEnclosingCircle(c)
    # 规范化为整数
    center = (int(x), int(y))
    radius = int(radius)
    # 勾画圆形区域
    img = cv2.circle(img, center, radius, (0, 255, 0), 2)

# # 轮廓绘制方法四
# 围绕图形勾画蓝色线条
cv2.drawContours(img, contours, -1, (255, 0, 0), 2)
# 显示图像
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-28-5ba1522adb50> in <module>
# ----> 1 img = cv2.pyrDown(cv2.imread(gray, cv2.IMREAD_UNCHANGED))
#       2 # threshold 函数对图像进行二化值处理，由于处理后图像对原图像有所变化，因此img.copy()生成新的图像，cv2.THRESH_BINARY是二化值
#       3 ret, thresh = cv2.threshold(cv2.cvtColor(img.copy(), cv2.COLOR_BGR2GRAY), 127, 255, cv2.THRESH_BINARY)
#       4 # findContours函数查找图像里的图形轮廓
#       5
#
# SystemError: <built-in function imread> returned NULL without setting an error

# %%
img = cv2.imread(pic,1)

# %%
#def examine(img):
temp_end = cv2.imread("/Users/nanzou/Documents/GitHub/walkr/mission/accept_button.png", 1)
res_end = cv2.matchTemplate(img, temp_end, cv2.TM_CCOEFF_NORMED)
end = cv2.minMaxLoc(res_end)[1]
#	return pic,end

# %%
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res_end)

# %%
cv2.imshow('img',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: MacOSX

# %%
from PIL import ImageGrab
select_range = ImageGrab.grab((100,max_loc[1],img.shape[1], max_loc[1] + 300))##截取电脑屏幕
plt.imshow(select_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2af63fe6a665> in <module>
#       1 from PIL import ImageGrab
# ----> 2 select_range = ImageGrab.grab((100,max_loc[1],img.shape[1], max_loc[1] + 300))##截取电脑屏幕
#       3 plt.imshow(select_range)
#
# NameError: name 'max_loc' is not defined

# %%
# min_loc/max_log[1] 即y 值很重要，vertical剪切起点。
cv2.rectangle(img, (0,max_loc[1]), (img.shape[1], max_loc[1] + 300), 0, 2)
# Out:
# array([[[29, 20,  6],
#         [29, 20,  6],
#         [29, 20,  6],
#         ...,
#         [29, 20,  6],
#         [29, 20,  6],
#         [29, 20,  6]],
#
#        [[29, 20,  6],
#         [29, 20,  6],
#         [29, 20,  6],
#         ...,
#         [29, 20,  6],
#         [29, 20,  6],
#         [29, 20,  6]],
#
#        [[29, 20,  6],
#         [29, 20,  6],
#         [29, 20,  6],
#         ...,
#         [29, 20,  6],
#         [29, 20,  6],
#         [29, 20,  6]],
#
#        ...,
#
#        [[45, 35, 17],
#         [45, 35, 17],
#         [45, 35, 17],
#         ...,
#         [45, 35, 17],
#         [45, 35, 17],
#         [45, 35, 17]],
#
#        [[45, 35, 17],
#         [45, 35, 17],
#         [45, 35, 17],
#         ...,
#         [45, 35, 17],
#         [45, 35, 17],
#         [45, 35, 17]],
#
#        [[45, 35, 17],
#         [45, 35, 17],
#         [45, 35, 17],
#         ...,
#         [45, 35, 17],
#         [45, 35, 17],
#         [45, 35, 17]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
min_loc
# Out:
# (283, 740)

# %%
import numpy as np

# %%
select_range = ImageGrab.grab((100,50,1050, 2100))##Screen location
plt.imshow(select_range)

# %%
img1 = cv2.cvtColor(np.asarray(select_range),cv2.COLOR_RGB2BGR)

# %%
temp_end = cv2.imread("/Users/nanzou/Documents/GitHub/walkr/mission/accept_button.png", 1)
accept_loc = cv2.matchTemplate(img_screen, temp_end, cv2.TM_CCOEFF_NORMED)

# %%
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(accept_loc)

# %%
mission_range = ImageGrab.grab((100,max_loc[1],1050, max_loc[1]+300))
plt.imshow(mission_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6ffad4eb5436> in <module>
# ----> 1 mission_range = ImageGrab.grab((100,max_loc[1],1050, max_loc[1]+300))
#       2 plt.imshow(mission_range)
#
# NameError: name 'max_loc' is not defined

# %%
mission_range = ImageGrab.grab((100,972,1050,1400))
plt.imshow(mission_range)

# %%
img_mission = cv2.cvtColor(np.asarray(mission_range),cv2.COLOR_RGB2BGR)
#cv2.circle(img_mission, max_loc, 50, (255, 0, 255), -1)
#cv2.circle(img_mission, min_loc, 50, (0, 0, 255), -1)
plt.imshow(img_mission)

# %%
import pytesseract
##img_mission = cv2.cvtColor(np.asarray(mission_range),cv2.COLOR_RGB2BGR)
text = pytesseract.image_to_string(img_mission)

# %%
print(text)
# Out:
# a Chicken Soup
#
# -_ Steam Mushrooms Chicken
# .0/400 ’0/600 '0/400
# REWARD I 7 .

# %%
plt.imshow(img2)

# %%
bf = cv2.BFMatcher(normType=cv2.NORM_L1, crossCheck=True)
matches = bf.match(des1,des2)
matches = sorted(matches, key = lambda x:x.distance)
img3 = cv2.drawMatches(img1=img_screen,keypoints1=kp1,img2=temp_end,keypoints2=kp2, matches1to2=matches, outImg=temp_end, flags=2)
plt.imshow(img3),plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-126-6d3637074bde> in <module>
#       1 bf = cv2.BFMatcher(normType=cv2.NORM_HAMMING, crossCheck=True)
# ----> 2 matches = bf.match(des1,des2)
#       3 matches = sorted(matches, key = lambda x:x.distance)
#       4 img3 = cv2.drawMatches(img1=img_screen,keypoints1=kp1,img2=temp_end,keypoints2=kp2, matches1to2=matches, outImg=temp_end, flags=2)
#       5 plt.imshow(img3),plt.show()
#
# error: OpenCV(4.2.0) /Users/travis/build/skvark/opencv-python/opencv/modules/core/src/batch_distance.cpp:275: error: (-215:Assertion failed) type == src2.type() && src1.cols == src2.cols && (type == CV_32F || type == CV_8U) in function 'batchDistance'

# %%
img1 = img_screen
img2 = temp_end

# %%
import copy
orb = cv2.ORB_create()

# Find the keypoints in the gray scale training image and compute their ORB descriptor.
# The None parameter is needed to indicate that we are not using a mask.
keypoints, descriptor = orb.detectAndCompute(img2, None)

# Create copies of the training image to draw our keypoints on
keyp_without_size = copy.copy(img2)
keyp_with_size = copy.copy(img2)

# Draw the keypoints without size or orientation on one copy of the training image 
cv2.drawKeypoints(img2, keypoints, keyp_without_size, color = (0, 255, 0))

# Draw the keypoints with size and orientation on the other copy of the training image
cv2.drawKeypoints(img2, keypoints, keyp_with_size, flags = cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# Display the image with the keypoints without size or orientation
plt.subplot(121)
plt.title('Keypoints Without Size or Orientation')
plt.imshow(keyp_without_size)

# Display the image with the keypoints with size and orientation
plt.subplot(122)
plt.title('Keypoints With Size and Orientation')
plt.imshow(keyp_with_size)
plt.show()

# Print the number of keypoints detected
print("\nNumber of keypoints Detected: ", len(keypoints))
# Out:
# Number of keypoints Detected:  283

# %%
# knnMatch 函数参数k是返回符合匹配的个数，暴力匹配match只返回最佳匹配结果。


# 使用plt将两个图像的第一个匹配结果显示出来
# 若使用knnMatch进行匹配，则需要使用drawMatchesKnn函数将结果显示
img3 = cv2.drawMatchesKnn(img1=img1,keypoints1=kp1,img2=img2,keypoints2=kp2, matches1to2=matches, outImg=img2, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x12416bed0>, None)

# %%
bf = cv2.BFMatcher(normType=cv2.NORM_HAMMING, crossCheck=True)

# %%
im_with_keypoints = cv2.drawKeypoints(img1, keypoints, np.array([]), (255,0,0), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
img2=cv2.imread('/Users/nanzou/Documents/GitHub/walkr/mission/WX20200411-185148@2x.png',1)

# %%
orb = cv2.ORB_create()
kp1, desc1 = orb.detectAndCompute(img1, None)
kp2, desc2 = orb.detectAndCompute(img2, None)

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.knnMatch(desc1, desc2, k=1)
